# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url='https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipo=pd.read_csv(url,sep='\t')
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
# 把金额的$符号去掉
chipo['price_float']=chipo.item_price.apply(lambda x:float(x[1:]))
chipo.head()
price_over10dollers=chipo.query('price_float>10.00')

# %%
price_over10dollers.item_name.nunique()
# Out:
# 31

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
chipo.loc[:,['item_name','item_price']]
chipo[(chipo['item_name'] == 'Chicken Bowl') & (chipo['quantity'] == 1)]
# Out:
#       order_id  quantity     item_name  \
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 42          20         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description item_price  \
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...     $8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...     $8.49
# 42    [Roasted Chili Corn Salsa, [Rice, Black Beans,...    $11.25
# ...                                                 ...        ...
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values(by='item_name')
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description item_price  \
# 3389                                        [Diet Coke]    $12.98
# 341                                         [Diet Coke]     $6.49
# 1849                                             [Coke]     $6.49
# 1860                                        [Diet Coke]     $6.49
# 2713                                             [Coke]     $6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
most_expensive=max(chipo.price_float/chipo.quantity) # 单价最贵的商品
chipo=chipo.assign(Unit_Price=lambda x:x.price_float/x.quantity) # 单价
chipo[chipo.Unit_Price == most_expensive]
# Out:
#       order_id  quantity            item_name  \
# 281        123         2     Steak Salad Bowl
# 606        250         1     Steak Salad Bowl
# 613        253         2     Steak Salad Bowl
# 749        309         1     Steak Salad Bowl
# 1132       468         1  Carnitas Salad Bowl
# 1159       478         1     Steak Salad Bowl
# 1229       501         1  Barbacoa Salad Bowl
# 1311       534         1     Steak Salad Bowl
# 1326       541         1  Barbacoa Salad Bowl
# 1505       612         1     Steak Salad Bowl
# 1571       637         1     Steak Salad Bowl
# 1590       644         1     Steak Salad Bowl
# 1816       734         1     Steak Salad Bowl
# 2401       953         1     Steak Salad Bowl
# 2439       969         1     Steak Salad Bowl
# 2442       970         1  Barbacoa Salad Bowl
# 2610      1035         1  Carnitas Salad Bowl
# 2740      1088         1     Steak Salad Bowl
# 2804      1114         1     Steak Salad Bowl
# ...

# %%
chipo[chipo.price_float == max(chipo.price_float)] #订单金额最大的一笔
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#      item_price  price_float  Unit_Price
# 3598    $44.25         44.25        2.95

# %%
chipo.sort_values('price_float',ascending=False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#      item_price  price_float  Unit_Price
# 3598    $44.25         44.25        2.95

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo[chipo.item_name=='Veggie Salad Bowl'].order_id.value_counts().count()
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
soda=chipo[(chipo.item_name=='Canned Soda')  & (chipo.quantity>1)]
soda
#chipo[(chipo.item_name == "Canned Soda") & (chipo.quantity > 1)]
# Out:
#       order_id  quantity    item_name choice_description item_price  \
# 18           9         2  Canned Soda           [Sprite]     $2.18
# 51          23         2  Canned Soda     [Mountain Dew]     $2.18
# 162         73         2  Canned Soda        [Diet Coke]     $2.18
# 171         76         2  Canned Soda  [Diet Dr. Pepper]     $2.18
# 350        150         2  Canned Soda        [Diet Coke]     $2.18
# 352        151         2  Canned Soda        [Coca Cola]     $2.18
# 698        287         2  Canned Soda        [Coca Cola]     $2.18
# 700        288         2  Canned Soda        [Coca Cola]     $2.18
# 909        376         2  Canned Soda     [Mountain Dew]     $2.18
# 1091       450         2  Canned Soda       [Dr. Pepper]     $2.18
# 1092       450         2  Canned Soda        [Coca Cola]     $2.18
# 1944       787         2  Canned Soda       [Dr. Pepper]     $2.18
# 2135       859         2  Canned Soda        [Diet Coke]     $2.18
# ...

# %%
len(soda)
# Out:
# 20
